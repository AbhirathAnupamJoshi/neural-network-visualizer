# %% [markdown]
# # Import Libraries

# %%
# %matplotlib inline

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Download Data

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %% [markdown]
# # Plot Examples

# %%
plt.figure(figsize=(10, 10))

for i in range(16):
    plt.subplot(4, 4, i + 1)
    plt.imshow(x_train[i], cmap='binary')
    plt.xlabel(str(y_train[i]))
    plt.xticks([])
    plt.yticks([])
plt.show()

# %% [markdown]
# # Normalize Data

# %%
x_train = np.reshape(x_train, (60000, 784))
x_train = x_train / 255.

x_test = np.reshape(x_test, (10000, 784))
x_test = x_test / 255.

# %% [markdown]
# # Create a Neural Network Model

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(32, activation='sigmoid', input_shape=(784,)),
    tf.keras.layers.Dense(32, activation='sigmoid'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# # Train the Model

# %%
_ = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),
    epochs=250, batch_size=2048,
    verbose=2
)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/250
# 60000/60000 - 0s - loss: 6.4683e-05 - accuracy: 1.0000 - val_loss: 0.3860 - val_accuracy: 0.9551
# Epoch 2/250
# 60000/60000 - 0s - loss: 6.3799e-05 - accuracy: 1.0000 - val_loss: 0.3878 - val_accuracy: 0.9553
# Epoch 3/250
# 60000/60000 - 0s - loss: 6.3237e-05 - accuracy: 1.0000 - val_loss: 0.3879 - val_accuracy: 0.9554
# Epoch 4/250
# 60000/60000 - 0s - loss: 6.2064e-05 - accuracy: 1.0000 - val_loss: 0.3896 - val_accuracy: 0.9549
# Epoch 5/250
# 60000/60000 - 0s - loss: 6.1998e-05 - accuracy: 1.0000 - val_loss: 0.3896 - val_accuracy: 0.9552
# Epoch 6/250
# 60000/60000 - 0s - loss: 6.1316e-05 - accuracy: 1.0000 - val_loss: 0.3899 - val_accuracy: 0.9552
# Epoch 7/250
# 60000/60000 - 0s - loss: 6.0583e-05 - accuracy: 1.0000 - val_loss: 0.3891 - val_accuracy: 0.9553
# Epoch 8/250
# 60000/60000 - 0s - loss: 5.9340e-05 - accuracy: 1.0000 - val_loss: 0.3908 - val_accuracy: 0.9551
# Epoch 9/250
# 60000/60000 - 0s - loss: 5.8485e-05 - accuracy: 1.0000 - val_loss: 0.3912 - val_accuracy: 0.9554
# Epoch 10/250
# 60000/60000 - 0s - loss: 5.8171e-05 - accuracy: 1.0000 - val_loss: 0.3926 - val_accuracy: 0.9549
# Epoch 11/250
# 60000/60000 - 0s - loss: 5.7465e-05 - accuracy: 1.0000 - val_loss: 0.3928 - val_accuracy: 0.9547
# Epoch 12/250
# 60000/60000 - 0s - loss: 5.6374e-05 - accuracy: 1.0000 - val_loss: 0.3935 - val_accuracy: 0.9554
# Epoch 13/250
# 60000/60000 - 0s - loss: 5.5556e-05 - accuracy: 1.0000 - val_loss: 0.3932 - val_accuracy: 0.9549
# Epoch 14/250
# 60000/60000 - 0s - loss: 5.4703e-05 - accuracy: 1.0000 - val_loss: 0.3952 - val_accuracy: 0.9554
# Epoch 15/250
# 60000/60000 - 0s - loss: 5.4631e-05 - accuracy: 1.0000 - val_loss: 0.3949 - val_accuracy: 0.9550
# Epoch 16/250
# 60000/60000 - 0s - loss: 5.3761e-05 - accuracy: 1.0000 - val_loss: 0.3951 - val_accuracy: 0.9553
# Epoch 17/250
# 60000/60000 - 0s - loss: 5.2825e-05 - accuracy: 1.0000 - val_loss: 0.3966 - val_accuracy: 0.9553
# Epoch 18/250
# 60000/60000 - 0s - loss: 5.1969e-05 - accuracy: 1.0000 - val_loss: 0.3964 - val_accuracy: 0.9551
# Epoch 19/250
# 60000/60000 - 0s - loss: 5.1392e-05 - accuracy: 1.0000 - val_loss: 0.3980 - val_accuracy: 0.9551
# Epoch 20/250
# 60000/60000 - 0s - loss: 5.0368e-05 - accuracy: 1.0000 - val_loss: 0.3980 - val_accuracy: 0.9552
# Epoch 21/250
# 60000/60000 - 0s - loss: 4.9708e-05 - accuracy: 1.0000 - val_loss: 0.3991 - val_accuracy: 0.9547
# Epoch 22/250
# 60000/60000 - 0s - loss: 4.9557e-05 - accuracy: 1.0000 - val_loss: 0.3980 - val_accuracy: 0.9553
# Epoch 23/250
# 60000/60000 - 0s - loss: 4.8913e-05 - accuracy: 1.0000 - val_loss: 0.3986 - val_accuracy: 0.9551
# Epoch 24/250
# 60000/60000 - 0s - loss: 4.8447e-05 - accuracy: 1.0000 - val_loss: 0.3991 - val_accuracy: 0.9553
# Epoch 25/250
# 60000/60000 - 0s - loss: 4.7598e-05 - accuracy: 1.0000 - val_loss: 0.4008 - val_accuracy: 0.9548
# Epoch 26/250
# 60000/60000 - 0s - loss: 4.6974e-05 - accuracy: 1.0000 - val_loss: 0.4011 - val_accuracy: 0.9545
# Epoch 27/250
# 60000/60000 - 0s - loss: 4.6689e-05 - accuracy: 1.0000 - val_loss: 0.4010 - val_accuracy: 0.9552
# Epoch 28/250
# 60000/60000 - 0s - loss: 4.5557e-05 - accuracy: 1.0000 - val_loss: 0.4022 - val_accuracy: 0.9549
# Epoch 29/250
# 60000/60000 - 1s - loss: 4.5294e-05 - accuracy: 1.0000 - val_loss: 0.4028 - val_accuracy: 0.9549
# Epoch 30/250
# 60000/60000 - 0s - loss: 4.4533e-05 - accuracy: 1.0000 - val_loss: 0.4040 - val_accuracy: 0.9546
# Epoch 31/250
# 60000/60000 - 0s - loss: 4.3929e-05 - accuracy: 1.0000 - val_loss: 0.4033 - val_accuracy: 0.9555
# Epoch 32/250
# 60000/60000 - 0s - loss: 4.3676e-05 - accuracy: 1.0000 - val_loss: 0.4039 - val_accuracy: 0.9552
# Epoch 33/250
# 60000/60000 - 0s - loss: 4.2690e-05 - accuracy: 1.0000 - val_loss: 0.4043 - val_accuracy: 0.9549
# Epoch 34/250
# 60000/60000 - 0s - loss: 4.2088e-05 - accuracy: 1.0000 - val_loss: 0.4060 - val_accuracy: 0.9552
# Epoch 35/250
# 60000/60000 - 0s - loss: 4.1852e-05 - accuracy: 1.0000 - val_loss: 0.4062 - val_accuracy: 0.9548
# Epoch 36/250
# 60000/60000 - 0s - loss: 4.1005e-05 - accuracy: 1.0000 - val_loss: 0.4061 - val_accuracy: 0.9551
# Epoch 37/250
# 60000/60000 - 1s - loss: 4.0671e-05 - accuracy: 1.0000 - val_loss: 0.4085 - val_accuracy: 0.9550
# Epoch 38/250
# 60000/60000 - 0s - loss: 4.0550e-05 - accuracy: 1.0000 - val_loss: 0.4073 - val_accuracy: 0.9551
# Epoch 39/250
# 60000/60000 - 0s - loss: 3.9776e-05 - accuracy: 1.0000 - val_loss: 0.4075 - val_accuracy: 0.9549
# Epoch 40/250
# 60000/60000 - 0s - loss: 3.8961e-05 - accuracy: 1.0000 - val_loss: 0.4090 - val_accuracy: 0.9546
# Epoch 41/250
# 60000/60000 - 0s - loss: 3.8467e-05 - accuracy: 1.0000 - val_loss: 0.4091 - val_accuracy: 0.9552
# Epoch 42/250
# 60000/60000 - 0s - loss: 3.9005e-05 - accuracy: 1.0000 - val_loss: 0.4086 - val_accuracy: 0.9551
# Epoch 43/250
# 60000/60000 - 0s - loss: 3.7837e-05 - accuracy: 1.0000 - val_loss: 0.4109 - val_accuracy: 0.9551
# Epoch 44/250
# 60000/60000 - 0s - loss: 3.7281e-05 - accuracy: 1.0000 - val_loss: 0.4113 - val_accuracy: 0.9548
# Epoch 45/250
# 60000/60000 - 0s - loss: 3.6366e-05 - accuracy: 1.0000 - val_loss: 0.4114 - val_accuracy: 0.9548
# Epoch 46/250
# 60000/60000 - 0s - loss: 3.6065e-05 - accuracy: 1.0000 - val_loss: 0.4128 - val_accuracy: 0.9549
# Epoch 47/250
# 60000/60000 - 0s - loss: 3.5848e-05 - accuracy: 1.0000 - val_loss: 0.4124 - val_accuracy: 0.9548
# Epoch 48/250
# 60000/60000 - 0s - loss: 3.5408e-05 - accuracy: 1.0000 - val_loss: 0.4125 - val_accuracy: 0.9551
# Epoch 49/250
# 60000/60000 - 0s - loss: 3.4851e-05 - accuracy: 1.0000 - val_loss: 0.4128 - val_accuracy: 0.9549
# Epoch 50/250
# 60000/60000 - 0s - loss: 3.4551e-05 - accuracy: 1.0000 - val_loss: 0.4136 - val_accuracy: 0.9548
# Epoch 51/250
# 60000/60000 - 0s - loss: 3.3769e-05 - accuracy: 1.0000 - val_loss: 0.4139 - val_accuracy: 0.9550
# Epoch 52/250
# 60000/60000 - 0s - loss: 3.3375e-05 - accuracy: 1.0000 - val_loss: 0.4148 - val_accuracy: 0.9551
# Epoch 53/250
# 60000/60000 - 0s - loss: 3.3294e-05 - accuracy: 1.0000 - val_loss: 0.4151 - val_accuracy: 0.9549
# Epoch 54/250
# 60000/60000 - 0s - loss: 3.2540e-05 - accuracy: 1.0000 - val_loss: 0.4166 - val_accuracy: 0.9550
# Epoch 55/250
# 60000/60000 - 0s - loss: 3.2767e-05 - accuracy: 1.0000 - val_loss: 0.4165 - val_accuracy: 0.9552
# Epoch 56/250
# 60000/60000 - 0s - loss: 3.1855e-05 - accuracy: 1.0000 - val_loss: 0.4174 - val_accuracy: 0.9548
# Epoch 57/250
# 60000/60000 - 0s - loss: 3.1854e-05 - accuracy: 1.0000 - val_loss: 0.4179 - val_accuracy: 0.9552
# Epoch 58/250
# 60000/60000 - 0s - loss: 3.1232e-05 - accuracy: 1.0000 - val_loss: 0.4174 - val_accuracy: 0.9549
# Epoch 59/250
# 60000/60000 - 0s - loss: 3.0584e-05 - accuracy: 1.0000 - val_loss: 0.4192 - val_accuracy: 0.9551
# Epoch 60/250
# 60000/60000 - 0s - loss: 3.0266e-05 - accuracy: 1.0000 - val_loss: 0.4193 - val_accuracy: 0.9549
# Epoch 61/250
# 60000/60000 - 0s - loss: 2.9919e-05 - accuracy: 1.0000 - val_loss: 0.4193 - val_accuracy: 0.9549
# Epoch 62/250
# 60000/60000 - 0s - loss: 2.9459e-05 - accuracy: 1.0000 - val_loss: 0.4204 - val_accuracy: 0.9552
# Epoch 63/250
# 60000/60000 - 0s - loss: 2.9078e-05 - accuracy: 1.0000 - val_loss: 0.4206 - val_accuracy: 0.9550
# Epoch 64/250
# 60000/60000 - 0s - loss: 2.8558e-05 - accuracy: 1.0000 - val_loss: 0.4214 - val_accuracy: 0.9549
# Epoch 65/250
# 60000/60000 - 0s - loss: 2.8242e-05 - accuracy: 1.0000 - val_loss: 0.4219 - val_accuracy: 0.9552
# Epoch 66/250
# 60000/60000 - 0s - loss: 2.7904e-05 - accuracy: 1.0000 - val_loss: 0.4232 - val_accuracy: 0.9550
# Epoch 67/250
# 60000/60000 - 0s - loss: 2.7527e-05 - accuracy: 1.0000 - val_loss: 0.4229 - val_accuracy: 0.9551
# Epoch 68/250
# 60000/60000 - 0s - loss: 2.7254e-05 - accuracy: 1.0000 - val_loss: 0.4236 - val_accuracy: 0.9548
# Epoch 69/250
# 60000/60000 - 0s - loss: 2.6826e-05 - accuracy: 1.0000 - val_loss: 0.4253 - val_accuracy: 0.9545
# Epoch 70/250
# 60000/60000 - 0s - loss: 2.6673e-05 - accuracy: 1.0000 - val_loss: 0.4254 - val_accuracy: 0.9548
# Epoch 71/250
# 60000/60000 - 0s - loss: 2.5994e-05 - accuracy: 1.0000 - val_loss: 0.4250 - val_accuracy: 0.9551
# Epoch 72/250
# 60000/60000 - 0s - loss: 2.5850e-05 - accuracy: 1.0000 - val_loss: 0.4269 - val_accuracy: 0.9549
# Epoch 73/250
# 60000/60000 - 0s - loss: 2.5689e-05 - accuracy: 1.0000 - val_loss: 0.4264 - val_accuracy: 0.9550
# Epoch 74/250
# 60000/60000 - 0s - loss: 2.5176e-05 - accuracy: 1.0000 - val_loss: 0.4273 - val_accuracy: 0.9548
# Epoch 75/250
# 60000/60000 - 0s - loss: 2.5036e-05 - accuracy: 1.0000 - val_loss: 0.4270 - val_accuracy: 0.9550
# Epoch 76/250
# 60000/60000 - 0s - loss: 2.4627e-05 - accuracy: 1.0000 - val_loss: 0.4283 - val_accuracy: 0.9547
# Epoch 77/250
# 60000/60000 - 0s - loss: 2.4379e-05 - accuracy: 1.0000 - val_loss: 0.4291 - val_accuracy: 0.9547
# Epoch 78/250
# 60000/60000 - 0s - loss: 2.3896e-05 - accuracy: 1.0000 - val_loss: 0.4290 - val_accuracy: 0.9547
# Epoch 79/250
# 60000/60000 - 0s - loss: 2.3542e-05 - accuracy: 1.0000 - val_loss: 0.4308 - val_accuracy: 0.9550
# Epoch 80/250
# 60000/60000 - 0s - loss: 2.3393e-05 - accuracy: 1.0000 - val_loss: 0.4288 - val_accuracy: 0.9547
# Epoch 81/250
# 60000/60000 - 0s - loss: 2.3264e-05 - accuracy: 1.0000 - val_loss: 0.4307 - val_accuracy: 0.9548
# Epoch 82/250
# 60000/60000 - 0s - loss: 2.2736e-05 - accuracy: 1.0000 - val_loss: 0.4318 - val_accuracy: 0.9547
# Epoch 83/250
# 60000/60000 - 0s - loss: 2.2535e-05 - accuracy: 1.0000 - val_loss: 0.4327 - val_accuracy: 0.9545
# Epoch 84/250
# 60000/60000 - 0s - loss: 2.2158e-05 - accuracy: 1.0000 - val_loss: 0.4326 - val_accuracy: 0.9549
# Epoch 85/250
# 60000/60000 - 0s - loss: 2.2084e-05 - accuracy: 1.0000 - val_loss: 0.4329 - val_accuracy: 0.9547
# Epoch 86/250
# 60000/60000 - 0s - loss: 2.2046e-05 - accuracy: 1.0000 - val_loss: 0.4332 - val_accuracy: 0.9551
# Epoch 87/250
# 60000/60000 - 0s - loss: 2.1505e-05 - accuracy: 1.0000 - val_loss: 0.4341 - val_accuracy: 0.9550
# Epoch 88/250
# 60000/60000 - 0s - loss: 2.1000e-05 - accuracy: 1.0000 - val_loss: 0.4342 - val_accuracy: 0.9547
# Epoch 89/250
# 60000/60000 - 0s - loss: 2.0776e-05 - accuracy: 1.0000 - val_loss: 0.4353 - val_accuracy: 0.9548
# Epoch 90/250
# 60000/60000 - 0s - loss: 2.0729e-05 - accuracy: 1.0000 - val_loss: 0.4353 - val_accuracy: 0.9547
# Epoch 91/250
# 60000/60000 - 0s - loss: 2.0238e-05 - accuracy: 1.0000 - val_loss: 0.4358 - val_accuracy: 0.9549
# Epoch 92/250
# 60000/60000 - 0s - loss: 2.0246e-05 - accuracy: 1.0000 - val_loss: 0.4362 - val_accuracy: 0.9550
# Epoch 93/250
# 60000/60000 - 0s - loss: 1.9786e-05 - accuracy: 1.0000 - val_loss: 0.4373 - val_accuracy: 0.9546
# Epoch 94/250
# 60000/60000 - 0s - loss: 1.9353e-05 - accuracy: 1.0000 - val_loss: 0.4374 - val_accuracy: 0.9548
# Epoch 95/250
# 60000/60000 - 0s - loss: 1.9184e-05 - accuracy: 1.0000 - val_loss: 0.4381 - val_accuracy: 0.9547
# Epoch 96/250
# 60000/60000 - 0s - loss: 1.8966e-05 - accuracy: 1.0000 - val_loss: 0.4379 - val_accuracy: 0.9544
# Epoch 97/250
# 60000/60000 - 0s - loss: 1.8717e-05 - accuracy: 1.0000 - val_loss: 0.4389 - val_accuracy: 0.9549
# Epoch 98/250
# 60000/60000 - 0s - loss: 1.8582e-05 - accuracy: 1.0000 - val_loss: 0.4384 - val_accuracy: 0.9545
# Epoch 99/250
# 60000/60000 - 0s - loss: 1.8245e-05 - accuracy: 1.0000 - val_loss: 0.4406 - val_accuracy: 0.9545
# Epoch 100/250
# 60000/60000 - 0s - loss: 1.7881e-05 - accuracy: 1.0000 - val_loss: 0.4405 - val_accuracy: 0.9551
# Epoch 101/250
# 60000/60000 - 0s - loss: 1.7800e-05 - accuracy: 1.0000 - val_loss: 0.4406 - val_accuracy: 0.9549
# Epoch 102/250
# 60000/60000 - 0s - loss: 1.7429e-05 - accuracy: 1.0000 - val_loss: 0.4415 - val_accuracy: 0.9547
# Epoch 103/250
# 60000/60000 - 0s - loss: 1.7384e-05 - accuracy: 1.0000 - val_loss: 0.4423 - val_accuracy: 0.9545
# Epoch 104/250
# 60000/60000 - 0s - loss: 1.7110e-05 - accuracy: 1.0000 - val_loss: 0.4433 - val_accuracy: 0.9547
# Epoch 105/250
# 60000/60000 - 0s - loss: 1.6874e-05 - accuracy: 1.0000 - val_loss: 0.4430 - val_accuracy: 0.9547
# Epoch 106/250
# 60000/60000 - 0s - loss: 1.6630e-05 - accuracy: 1.0000 - val_loss: 0.4430 - val_accuracy: 0.9549
# Epoch 107/250
# 60000/60000 - 0s - loss: 1.6440e-05 - accuracy: 1.0000 - val_loss: 0.4442 - val_accuracy: 0.9546
# Epoch 108/250
# 60000/60000 - 0s - loss: 1.6324e-05 - accuracy: 1.0000 - val_loss: 0.4447 - val_accuracy: 0.9549
# Epoch 109/250
# 60000/60000 - 0s - loss: 1.6160e-05 - accuracy: 1.0000 - val_loss: 0.4446 - val_accuracy: 0.9551
# Epoch 110/250
# 60000/60000 - 0s - loss: 1.5788e-05 - accuracy: 1.0000 - val_loss: 0.4457 - val_accuracy: 0.9547
# Epoch 111/250
# 60000/60000 - 0s - loss: 1.5703e-05 - accuracy: 1.0000 - val_loss: 0.4472 - val_accuracy: 0.9547
# Epoch 112/250
# 60000/60000 - 0s - loss: 1.5798e-05 - accuracy: 1.0000 - val_loss: 0.4483 - val_accuracy: 0.9545
# Epoch 113/250
# 60000/60000 - 0s - loss: 1.5372e-05 - accuracy: 1.0000 - val_loss: 0.4472 - val_accuracy: 0.9549
# Epoch 114/250
# 60000/60000 - 0s - loss: 1.5140e-05 - accuracy: 1.0000 - val_loss: 0.4494 - val_accuracy: 0.9548
# Epoch 115/250
# 60000/60000 - 0s - loss: 1.5041e-05 - accuracy: 1.0000 - val_loss: 0.4491 - val_accuracy: 0.9546
# Epoch 116/250
# 60000/60000 - 0s - loss: 1.4651e-05 - accuracy: 1.0000 - val_loss: 0.4485 - val_accuracy: 0.9547
# Epoch 117/250
# 60000/60000 - 0s - loss: 1.4549e-05 - accuracy: 1.0000 - val_loss: 0.4503 - val_accuracy: 0.9547
# Epoch 118/250
# 60000/60000 - 0s - loss: 1.4245e-05 - accuracy: 1.0000 - val_loss: 0.4509 - val_accuracy: 0.9546
# Epoch 119/250
# 60000/60000 - 0s - loss: 1.4153e-05 - accuracy: 1.0000 - val_loss: 0.4512 - val_accuracy: 0.9546
# Epoch 120/250
# 60000/60000 - 0s - loss: 1.4099e-05 - accuracy: 1.0000 - val_loss: 0.4501 - val_accuracy: 0.9550
# Epoch 121/250
# 60000/60000 - 0s - loss: 1.3764e-05 - accuracy: 1.0000 - val_loss: 0.4529 - val_accuracy: 0.9549
# Epoch 122/250
# 60000/60000 - 0s - loss: 1.3670e-05 - accuracy: 1.0000 - val_loss: 0.4531 - val_accuracy: 0.9545
# Epoch 123/250
# 60000/60000 - 0s - loss: 1.3495e-05 - accuracy: 1.0000 - val_loss: 0.4525 - val_accuracy: 0.9550
# Epoch 124/250
# 60000/60000 - 0s - loss: 1.3321e-05 - accuracy: 1.0000 - val_loss: 0.4547 - val_accuracy: 0.9545
# Epoch 125/250
# 60000/60000 - 0s - loss: 1.3202e-05 - accuracy: 1.0000 - val_loss: 0.4535 - val_accuracy: 0.9546
# Epoch 126/250
# 60000/60000 - 0s - loss: 1.3038e-05 - accuracy: 1.0000 - val_loss: 0.4546 - val_accuracy: 0.9548
# Epoch 127/250
# 60000/60000 - 0s - loss: 1.2843e-05 - accuracy: 1.0000 - val_loss: 0.4556 - val_accuracy: 0.9548
# Epoch 128/250
# 60000/60000 - 0s - loss: 1.2660e-05 - accuracy: 1.0000 - val_loss: 0.4558 - val_accuracy: 0.9549
# Epoch 129/250
# 60000/60000 - 0s - loss: 1.2487e-05 - accuracy: 1.0000 - val_loss: 0.4557 - val_accuracy: 0.9545
# Epoch 130/250
# 60000/60000 - 0s - loss: 1.2202e-05 - accuracy: 1.0000 - val_loss: 0.4564 - val_accuracy: 0.9548
# Epoch 131/250
# 60000/60000 - 0s - loss: 1.2099e-05 - accuracy: 1.0000 - val_loss: 0.4579 - val_accuracy: 0.9543
# Epoch 132/250
# 60000/60000 - 0s - loss: 1.2048e-05 - accuracy: 1.0000 - val_loss: 0.4586 - val_accuracy: 0.9545
# Epoch 133/250
# 60000/60000 - 0s - loss: 1.1900e-05 - accuracy: 1.0000 - val_loss: 0.4586 - val_accuracy: 0.9545
# Epoch 134/250
# 60000/60000 - 0s - loss: 1.1837e-05 - accuracy: 1.0000 - val_loss: 0.4592 - val_accuracy: 0.9545
# Epoch 135/250
# 60000/60000 - 0s - loss: 1.1574e-05 - accuracy: 1.0000 - val_loss: 0.4582 - val_accuracy: 0.9546
# Epoch 136/250
# 60000/60000 - 0s - loss: 1.1453e-05 - accuracy: 1.0000 - val_loss: 0.4587 - val_accuracy: 0.9547
# Epoch 137/250
# 60000/60000 - 0s - loss: 1.1243e-05 - accuracy: 1.0000 - val_loss: 0.4599 - val_accuracy: 0.9545
# Epoch 138/250
# 60000/60000 - 0s - loss: 1.1161e-05 - accuracy: 1.0000 - val_loss: 0.4609 - val_accuracy: 0.9544
# Epoch 139/250
# 60000/60000 - 0s - loss: 1.1068e-05 - accuracy: 1.0000 - val_loss: 0.4621 - val_accuracy: 0.9546
# Epoch 140/250
# 60000/60000 - 0s - loss: 1.0845e-05 - accuracy: 1.0000 - val_loss: 0.4619 - val_accuracy: 0.9544
# Epoch 141/250
# 60000/60000 - 0s - loss: 1.0752e-05 - accuracy: 1.0000 - val_loss: 0.4623 - val_accuracy: 0.9546
# Epoch 142/250
# 60000/60000 - 0s - loss: 1.0565e-05 - accuracy: 1.0000 - val_loss: 0.4618 - val_accuracy: 0.9547
# Epoch 143/250
# 60000/60000 - 0s - loss: 1.0410e-05 - accuracy: 1.0000 - val_loss: 0.4627 - val_accuracy: 0.9547
# Epoch 144/250
# 60000/60000 - 0s - loss: 1.0353e-05 - accuracy: 1.0000 - val_loss: 0.4642 - val_accuracy: 0.9550
# Epoch 145/250
# 60000/60000 - 0s - loss: 1.0163e-05 - accuracy: 1.0000 - val_loss: 0.4644 - val_accuracy: 0.9545
# Epoch 146/250
# 60000/60000 - 0s - loss: 1.0146e-05 - accuracy: 1.0000 - val_loss: 0.4657 - val_accuracy: 0.9550
# Epoch 147/250
# 60000/60000 - 0s - loss: 9.9338e-06 - accuracy: 1.0000 - val_loss: 0.4659 - val_accuracy: 0.9546
# Epoch 148/250
# 60000/60000 - 0s - loss: 9.8015e-06 - accuracy: 1.0000 - val_loss: 0.4656 - val_accuracy: 0.9546
# Epoch 149/250
# 60000/60000 - 0s - loss: 9.8073e-06 - accuracy: 1.0000 - val_loss: 0.4671 - val_accuracy: 0.9549
# Epoch 150/250
# 60000/60000 - 0s - loss: 9.6314e-06 - accuracy: 1.0000 - val_loss: 0.4668 - val_accuracy: 0.9548
# Epoch 151/250
# 60000/60000 - 0s - loss: 9.6169e-06 - accuracy: 1.0000 - val_loss: 0.4665 - val_accuracy: 0.9546
# Epoch 152/250
# 60000/60000 - 0s - loss: 9.3527e-06 - accuracy: 1.0000 - val_loss: 0.4678 - val_accuracy: 0.9545
# Epoch 153/250
# 60000/60000 - 0s - loss: 9.2028e-06 - accuracy: 1.0000 - val_loss: 0.4691 - val_accuracy: 0.9544
# Epoch 154/250
# 60000/60000 - 0s - loss: 9.0407e-06 - accuracy: 1.0000 - val_loss: 0.4692 - val_accuracy: 0.9544
# Epoch 155/250
# 60000/60000 - 0s - loss: 8.9792e-06 - accuracy: 1.0000 - val_loss: 0.4702 - val_accuracy: 0.9549
# Epoch 156/250
# 60000/60000 - 0s - loss: 8.9091e-06 - accuracy: 1.0000 - val_loss: 0.4692 - val_accuracy: 0.9546
# Epoch 157/250
# 60000/60000 - 0s - loss: 8.8596e-06 - accuracy: 1.0000 - val_loss: 0.4706 - val_accuracy: 0.9543
# Epoch 158/250
# 60000/60000 - 0s - loss: 8.6774e-06 - accuracy: 1.0000 - val_loss: 0.4702 - val_accuracy: 0.9547
# Epoch 159/250
# 60000/60000 - 0s - loss: 8.6295e-06 - accuracy: 1.0000 - val_loss: 0.4711 - val_accuracy: 0.9545
# Epoch 160/250
# 60000/60000 - 0s - loss: 8.4361e-06 - accuracy: 1.0000 - val_loss: 0.4712 - val_accuracy: 0.9548
# Epoch 161/250
# 60000/60000 - 0s - loss: 8.3278e-06 - accuracy: 1.0000 - val_loss: 0.4720 - val_accuracy: 0.9547
# Epoch 162/250
# 60000/60000 - 0s - loss: 8.2769e-06 - accuracy: 1.0000 - val_loss: 0.4731 - val_accuracy: 0.9546
# Epoch 163/250
# 60000/60000 - 0s - loss: 8.0815e-06 - accuracy: 1.0000 - val_loss: 0.4741 - val_accuracy: 0.9546
# Epoch 164/250
# 60000/60000 - 0s - loss: 8.0320e-06 - accuracy: 1.0000 - val_loss: 0.4735 - val_accuracy: 0.9547
# Epoch 165/250
# 60000/60000 - 0s - loss: 7.9125e-06 - accuracy: 1.0000 - val_loss: 0.4741 - val_accuracy: 0.9546
# Epoch 166/250
# 60000/60000 - 0s - loss: 7.8091e-06 - accuracy: 1.0000 - val_loss: 0.4749 - val_accuracy: 0.9546
# Epoch 167/250
# 60000/60000 - 0s - loss: 7.7436e-06 - accuracy: 1.0000 - val_loss: 0.4752 - val_accuracy: 0.9547
# Epoch 168/250
# 60000/60000 - 0s - loss: 7.6261e-06 - accuracy: 1.0000 - val_loss: 0.4765 - val_accuracy: 0.9546
# Epoch 169/250
# 60000/60000 - 0s - loss: 7.5583e-06 - accuracy: 1.0000 - val_loss: 0.4765 - val_accuracy: 0.9546
# Epoch 170/250
# 60000/60000 - 0s - loss: 7.4652e-06 - accuracy: 1.0000 - val_loss: 0.4776 - val_accuracy: 0.9547
# Epoch 171/250
# 60000/60000 - 0s - loss: 7.4352e-06 - accuracy: 1.0000 - val_loss: 0.4768 - val_accuracy: 0.9545
# Epoch 172/250
# 60000/60000 - 0s - loss: 7.2450e-06 - accuracy: 1.0000 - val_loss: 0.4780 - val_accuracy: 0.9547
# Epoch 173/250
# 60000/60000 - 0s - loss: 7.2467e-06 - accuracy: 1.0000 - val_loss: 0.4786 - val_accuracy: 0.9547
# Epoch 174/250
# 60000/60000 - 0s - loss: 7.1358e-06 - accuracy: 1.0000 - val_loss: 0.4788 - val_accuracy: 0.9546
# Epoch 175/250
# 60000/60000 - 0s - loss: 6.9792e-06 - accuracy: 1.0000 - val_loss: 0.4810 - val_accuracy: 0.9546
# Epoch 176/250
# 60000/60000 - 0s - loss: 6.9375e-06 - accuracy: 1.0000 - val_loss: 0.4796 - val_accuracy: 0.9543
# Epoch 177/250
# 60000/60000 - 0s - loss: 6.8961e-06 - accuracy: 1.0000 - val_loss: 0.4813 - val_accuracy: 0.9545
# Epoch 178/250
# 60000/60000 - 0s - loss: 6.7785e-06 - accuracy: 1.0000 - val_loss: 0.4826 - val_accuracy: 0.9541
# Epoch 179/250
# 60000/60000 - 0s - loss: 6.7302e-06 - accuracy: 1.0000 - val_loss: 0.4811 - val_accuracy: 0.9543
# Epoch 180/250
# 60000/60000 - 0s - loss: 6.5894e-06 - accuracy: 1.0000 - val_loss: 0.4824 - val_accuracy: 0.9548
# Epoch 181/250
# 60000/60000 - 0s - loss: 6.5687e-06 - accuracy: 1.0000 - val_loss: 0.4815 - val_accuracy: 0.9545
# Epoch 182/250
# 60000/60000 - 0s - loss: 6.4529e-06 - accuracy: 1.0000 - val_loss: 0.4845 - val_accuracy: 0.9548
# Epoch 183/250
# 60000/60000 - 0s - loss: 6.4525e-06 - accuracy: 1.0000 - val_loss: 0.4834 - val_accuracy: 0.9546
# Epoch 184/250
# 60000/60000 - 0s - loss: 6.3329e-06 - accuracy: 1.0000 - val_loss: 0.4848 - val_accuracy: 0.9544
# Epoch 185/250
# 60000/60000 - 0s - loss: 6.2475e-06 - accuracy: 1.0000 - val_loss: 0.4849 - val_accuracy: 0.9542
# Epoch 186/250
# 60000/60000 - 0s - loss: 6.2542e-06 - accuracy: 1.0000 - val_loss: 0.4853 - val_accuracy: 0.9545
# Epoch 187/250
# 60000/60000 - 0s - loss: 6.1510e-06 - accuracy: 1.0000 - val_loss: 0.4850 - val_accuracy: 0.9544
# Epoch 188/250
# 60000/60000 - 0s - loss: 6.0361e-06 - accuracy: 1.0000 - val_loss: 0.4858 - val_accuracy: 0.9546
# Epoch 189/250
# 60000/60000 - 0s - loss: 5.9840e-06 - accuracy: 1.0000 - val_loss: 0.4861 - val_accuracy: 0.9545
# Epoch 190/250
# 60000/60000 - 0s - loss: 5.8336e-06 - accuracy: 1.0000 - val_loss: 0.4870 - val_accuracy: 0.9545
# Epoch 191/250
# 60000/60000 - 0s - loss: 5.7817e-06 - accuracy: 1.0000 - val_loss: 0.4877 - val_accuracy: 0.9547
# Epoch 192/250
# 60000/60000 - 0s - loss: 5.7111e-06 - accuracy: 1.0000 - val_loss: 0.4874 - val_accuracy: 0.9545
# Epoch 193/250
# 60000/60000 - 0s - loss: 5.6186e-06 - accuracy: 1.0000 - val_loss: 0.4882 - val_accuracy: 0.9544
# Epoch 194/250
# 60000/60000 - 0s - loss: 5.6140e-06 - accuracy: 1.0000 - val_loss: 0.4904 - val_accuracy: 0.9545
# Epoch 195/250
# 60000/60000 - 0s - loss: 5.5495e-06 - accuracy: 1.0000 - val_loss: 0.4900 - val_accuracy: 0.9544
# Epoch 196/250
# 60000/60000 - 0s - loss: 5.4462e-06 - accuracy: 1.0000 - val_loss: 0.4914 - val_accuracy: 0.9548
# Epoch 197/250
# 60000/60000 - 0s - loss: 5.3589e-06 - accuracy: 1.0000 - val_loss: 0.4901 - val_accuracy: 0.9545
# Epoch 198/250
# 60000/60000 - 0s - loss: 5.3696e-06 - accuracy: 1.0000 - val_loss: 0.4907 - val_accuracy: 0.9546
# Epoch 199/250
# 60000/60000 - 0s - loss: 5.3035e-06 - accuracy: 1.0000 - val_loss: 0.4915 - val_accuracy: 0.9544
# Epoch 200/250
# 60000/60000 - 0s - loss: 5.2144e-06 - accuracy: 1.0000 - val_loss: 0.4927 - val_accuracy: 0.9541
# Epoch 201/250
# 60000/60000 - 0s - loss: 5.1937e-06 - accuracy: 1.0000 - val_loss: 0.4930 - val_accuracy: 0.9544
# Epoch 202/250
# 60000/60000 - 0s - loss: 5.0563e-06 - accuracy: 1.0000 - val_loss: 0.4940 - val_accuracy: 0.9541
# Epoch 203/250
# 60000/60000 - 0s - loss: 5.0226e-06 - accuracy: 1.0000 - val_loss: 0.4932 - val_accuracy: 0.9545
# Epoch 204/250
# 60000/60000 - 0s - loss: 4.9800e-06 - accuracy: 1.0000 - val_loss: 0.4936 - val_accuracy: 0.9544
# Epoch 205/250
# 60000/60000 - 0s - loss: 4.9155e-06 - accuracy: 1.0000 - val_loss: 0.4937 - val_accuracy: 0.9544
# Epoch 206/250
# 60000/60000 - 0s - loss: 4.8294e-06 - accuracy: 1.0000 - val_loss: 0.4956 - val_accuracy: 0.9542
# Epoch 207/250
# 60000/60000 - 0s - loss: 4.8448e-06 - accuracy: 1.0000 - val_loss: 0.4951 - val_accuracy: 0.9546
# Epoch 208/250
# 60000/60000 - 0s - loss: 4.7770e-06 - accuracy: 1.0000 - val_loss: 0.4956 - val_accuracy: 0.9541
# Epoch 209/250
# 60000/60000 - 0s - loss: 4.6681e-06 - accuracy: 1.0000 - val_loss: 0.4966 - val_accuracy: 0.9540
# Epoch 210/250
# 60000/60000 - 0s - loss: 4.6150e-06 - accuracy: 1.0000 - val_loss: 0.4979 - val_accuracy: 0.9547
# Epoch 211/250
# 60000/60000 - 0s - loss: 4.5987e-06 - accuracy: 1.0000 - val_loss: 0.4978 - val_accuracy: 0.9543
# Epoch 212/250
# 60000/60000 - 0s - loss: 4.5774e-06 - accuracy: 1.0000 - val_loss: 0.4983 - val_accuracy: 0.9547
# Epoch 213/250
# 60000/60000 - 0s - loss: 4.5119e-06 - accuracy: 1.0000 - val_loss: 0.4997 - val_accuracy: 0.9539
# Epoch 214/250
# 60000/60000 - 0s - loss: 4.4617e-06 - accuracy: 1.0000 - val_loss: 0.4984 - val_accuracy: 0.9540
# Epoch 215/250
# 60000/60000 - 0s - loss: 4.3709e-06 - accuracy: 1.0000 - val_loss: 0.4988 - val_accuracy: 0.9546
# Epoch 216/250
# 60000/60000 - 0s - loss: 4.3167e-06 - accuracy: 1.0000 - val_loss: 0.4995 - val_accuracy: 0.9543
# Epoch 217/250
# 60000/60000 - 0s - loss: 4.2548e-06 - accuracy: 1.0000 - val_loss: 0.5002 - val_accuracy: 0.9542
# Epoch 218/250
# 60000/60000 - 0s - loss: 4.2104e-06 - accuracy: 1.0000 - val_loss: 0.5008 - val_accuracy: 0.9541
# Epoch 219/250
# 60000/60000 - 0s - loss: 4.1835e-06 - accuracy: 1.0000 - val_loss: 0.5018 - val_accuracy: 0.9543
# Epoch 220/250
# 60000/60000 - 0s - loss: 4.1431e-06 - accuracy: 1.0000 - val_loss: 0.5022 - val_accuracy: 0.9544
# Epoch 221/250
# 60000/60000 - 0s - loss: 4.1345e-06 - accuracy: 1.0000 - val_loss: 0.5033 - val_accuracy: 0.9541
# Epoch 222/250
# 60000/60000 - 0s - loss: 4.1168e-06 - accuracy: 1.0000 - val_loss: 0.5025 - val_accuracy: 0.9544
# Epoch 223/250
# 60000/60000 - 0s - loss: 4.0105e-06 - accuracy: 1.0000 - val_loss: 0.5026 - val_accuracy: 0.9543
# Epoch 224/250
# 60000/60000 - 0s - loss: 3.9378e-06 - accuracy: 1.0000 - val_loss: 0.5033 - val_accuracy: 0.9544
# Epoch 225/250
# 60000/60000 - 0s - loss: 3.8758e-06 - accuracy: 1.0000 - val_loss: 0.5044 - val_accuracy: 0.9544
# Epoch 226/250
# 60000/60000 - 0s - loss: 3.8337e-06 - accuracy: 1.0000 - val_loss: 0.5042 - val_accuracy: 0.9542
# Epoch 227/250
# 60000/60000 - 0s - loss: 3.7860e-06 - accuracy: 1.0000 - val_loss: 0.5057 - val_accuracy: 0.9543
# Epoch 228/250
# 60000/60000 - 0s - loss: 3.7220e-06 - accuracy: 1.0000 - val_loss: 0.5059 - val_accuracy: 0.9542
# Epoch 229/250
# 60000/60000 - 0s - loss: 3.7292e-06 - accuracy: 1.0000 - val_loss: 0.5062 - val_accuracy: 0.9543
# Epoch 230/250
# 60000/60000 - 0s - loss: 3.6589e-06 - accuracy: 1.0000 - val_loss: 0.5068 - val_accuracy: 0.9541
# Epoch 231/250
# 60000/60000 - 0s - loss: 3.6501e-06 - accuracy: 1.0000 - val_loss: 0.5066 - val_accuracy: 0.9544
# Epoch 232/250
# 60000/60000 - 0s - loss: 3.5606e-06 - accuracy: 1.0000 - val_loss: 0.5072 - val_accuracy: 0.9538
# Epoch 233/250
# 60000/60000 - 0s - loss: 3.5592e-06 - accuracy: 1.0000 - val_loss: 0.5085 - val_accuracy: 0.9545
# Epoch 234/250
# 60000/60000 - 0s - loss: 3.5080e-06 - accuracy: 1.0000 - val_loss: 0.5085 - val_accuracy: 0.9545
# Epoch 235/250
# 60000/60000 - 0s - loss: 3.4629e-06 - accuracy: 1.0000 - val_loss: 0.5091 - val_accuracy: 0.9544
# Epoch 236/250
# 60000/60000 - 0s - loss: 3.4250e-06 - accuracy: 1.0000 - val_loss: 0.5089 - val_accuracy: 0.9541
# Epoch 237/250
# 60000/60000 - 0s - loss: 3.3759e-06 - accuracy: 1.0000 - val_loss: 0.5100 - val_accuracy: 0.9546
# Epoch 238/250
# 60000/60000 - 0s - loss: 3.3471e-06 - accuracy: 1.0000 - val_loss: 0.5105 - val_accuracy: 0.9544
# Epoch 239/250
# 60000/60000 - 0s - loss: 3.3279e-06 - accuracy: 1.0000 - val_loss: 0.5106 - val_accuracy: 0.9542
# Epoch 240/250
# 60000/60000 - 0s - loss: 3.2874e-06 - accuracy: 1.0000 - val_loss: 0.5114 - val_accuracy: 0.9542
# Epoch 241/250
# 60000/60000 - 0s - loss: 3.2286e-06 - accuracy: 1.0000 - val_loss: 0.5110 - val_accuracy: 0.9545
# Epoch 242/250
# 60000/60000 - 0s - loss: 3.2363e-06 - accuracy: 1.0000 - val_loss: 0.5123 - val_accuracy: 0.9544
# Epoch 243/250
# 60000/60000 - 0s - loss: 3.2524e-06 - accuracy: 1.0000 - val_loss: 0.5129 - val_accuracy: 0.9547
# Epoch 244/250
# 60000/60000 - 0s - loss: 3.1492e-06 - accuracy: 1.0000 - val_loss: 0.5126 - val_accuracy: 0.9539
# Epoch 245/250
# 60000/60000 - 0s - loss: 3.1201e-06 - accuracy: 1.0000 - val_loss: 0.5139 - val_accuracy: 0.9545
# Epoch 246/250
# 60000/60000 - 0s - loss: 3.0642e-06 - accuracy: 1.0000 - val_loss: 0.5131 - val_accuracy: 0.9542
# Epoch 247/250
# 60000/60000 - 0s - loss: 3.0354e-06 - accuracy: 1.0000 - val_loss: 0.5148 - val_accuracy: 0.9546
# Epoch 248/250
# 60000/60000 - 0s - loss: 3.0120e-06 - accuracy: 1.0000 - val_loss: 0.5142 - val_accuracy: 0.9540
# Epoch 249/250
# 60000/60000 - 0s - loss: 3.0074e-06 - accuracy: 1.0000 - val_loss: 0.5156 - val_accuracy: 0.9545
# Epoch 250/250
# 60000/60000 - 0s - loss: 2.9358e-06 - accuracy: 1.0000 - val_loss: 0.5157 - val_accuracy: 0.9543

# %% [markdown]
# # Save the Model

# %%
model.save('model.h5')

# %%
# %%writefile ml_server.py

import json
import tensorflow as tf
import numpy as np
import random

from flask import Flask, request

app = Flask(__name__)

model = tf.keras.models.load_model('model.h5')
feature_model = tf.keras.models.Model(
    model.inputs,
    [layer.output for layer in model.layers]
)

_, (x_test, _) = tf.keras.datasets.mnist.load_data()
x_test = x_test / 255.

def get_prediction():
  index = np.random.choice(x_test.shape[0])
  image = x_test[index, :, :]
  image_arr = np.reshape(image, (1, 784))
  return feature_model.predict(image_arr), image


@app.route('/', methods = ['GET', 'POST'])
def index() :
  if request.method == 'POST':
    preds, image = get_prediction()
    final_preds = [p.tolist() for p in preds]
    return json.dumps({
        'prediction': final_preds,
        'image': image.tolist()
    })
  return 'Welcome to the model server!'

if __name__ == '__main__':
  app.run()
# Out:
# Overwriting ml_server.py

# %%
# %%writefile app.py

import requests
import json
import numpy as np
import streamlit as st
import os
import matplotlib.pyplot as plt

URI = 'http://127.0.0.1:5000'

st.title('Neural Network Visualizer')
st.sidebar.markdown('# Input Image')

if st.button('Get random predictions'):
    response = requests.post(URI, data={})
    # print(response.text)
    response = json.loads(response.text)
    preds = response.get('prediction')
    image = response.get('image')
    image = np.reshape(image, (28, 28))

    st.sidebar.image(image, width=150)

    for layer, p in enumerate(preds):
        numbers = np.squeeze(np.array(p))

        plt.figure(figsize=(32, 4))

        if layer == 2:
            row = 1
            col = 10
        else:
            row = 2
            col = 16

        for i, number in enumerate(numbers):
            plt.subplot(row, col, i + 1)
            plt.imshow((number * np.ones((8, 8, 3))).astype('float32'), cmap='binary')
            plt.xticks([])
            plt.yticks([])
            if layer == 2:
                plt.xlabel(str(i), fontsize=40)
        plt.subplots_adjust(wspace=0.05, hspace=0.05)
        plt.tight_layout()

        st.text('Layer {}'.format(layer + 1), )
        st.pyplot()
# Out:
# Overwriting app.py
